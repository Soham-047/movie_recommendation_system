# %%
import pandas as pd

# %%
movies = pd.read_csv("datasets/movies.csv")

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 62418                                        Drama
# 62419                                  Documentary
# 62420                                 Comedy|Drama
# 62421                           (no genres listed)
# 62422                       Action|Adventure|Drama
#
# [62423 rows x 3 columns]

# %%
import re
def clean_title(title):
    return re.sub("[^a-zA-z0-9 ]", "", title)

movies['cleaned_title'] = movies["title"].apply(clean_title)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(ngram_range=(1, 2))

tfidf = vectorizer.fit_transform(movies['title'])

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
import numpy as np

# %%
def search(title):
    title = clean_title(title)
    query_vec = vectorizer.transform([title])
    
    similarity = cosine_similarity(query_vec, tfidf).flatten()
    indices = np.argpartition(similarity, -5)[-5:]
    results = movies.iloc[indices][::-1]

    return results

# %%
search("Avengers")
# Out:
#        movieId                       title                        genres  \
# 34536   145676           3 Avengers (1964)            (no genres listed)
# 2063      2153        Avengers, The (1998)              Action|Adventure
# 17067    89745        Avengers, The (2012)  Action|Adventure|Sci-Fi|IMAX
# 40636   159920     Shaolin Avengers (1994)                        Action
# 45394   170297  Ultimate Avengers 2 (2006)       Action|Animation|Sci-Fi
#
#                   cleaned_title
# 34536           3 Avengers 1964
# 2063          Avengers The 1998
# 17067         Avengers The 2012
# 40636     Shaolin Avengers 1994
# 45394  Ultimate Avengers 2 2006

# %%
import ipywidgets as widgets
from IPython.display import display

movie_input = widgets.Text(
    value="Toy Story",
    description="Movie Title: ",
    disabled=False
)

movie_list = widgets.Output()

def on_type(data):
    print("Fired")
    with movie_list:
        movie_list.clear_output()
        title = data["new"]
        
        if len(title) > 2:   
            display(search(title))

movie_input.observe(on_type, names='value')
display(movie_input, movie_list)
# Out:
# Text(value='Toy Story', description='Movie Title: ')
# Output()

# %%
ratings = pd.read_csv("datasets/ratings.csv")

# %%
ratings
# Out:
#           userId  movieId  rating     timestamp
# 0              1      296     5.0  1.147880e+09
# 1              1      306     3.5  1.147869e+09
# 2              1      307     5.0  1.147869e+09
# 3              1      665     5.0  1.147879e+09
# 4              1      899     3.5  1.147869e+09
# ...          ...      ...     ...           ...
# 15232122   98680    55765     2.0  1.437718e+09
# 15232123   98680    55805     5.0  1.437719e+09
# 15232124   98680    55820     5.0  1.437718e+09
# 15232125   98680    55908     1.5  1.437719e+09
# 15232126   98680      559     NaN           NaN
#
# [15232127 rows x 4 columns]

# %%
ratings.dtypes
# Out:
# userId         int64
# movieId        int64
# rating       float64
# timestamp    float64
# dtype: object

# %%
movie_id = 137

# %%
similar_users = ratings[(ratings["movieId"] == movie_id) & (ratings["rating"] >= 4)]["userId"].unique()

# %%
similar_users
# Out:
# array([ 3226,  5990,  6123,  8315, 14626, 15878, 15938, 16517, 17149,
#        19143, 19649, 24974, 29574, 30267, 31827, 31887, 32505, 37754,
#        40210, 43269, 44711, 47458, 47628, 48097, 49996, 52071, 53538,
#        61141, 63503, 64415, 67456, 71351, 71362, 72641, 74979, 75421,
#        80895, 83094, 85293, 87485, 87564, 89411, 89616, 92096, 96555,
#        98118])

# %%
similar_user_recs = ratings[(ratings['userId'].isin(similar_users)) & (ratings["rating"] >= 4)]['movieId']

# %%
similar_user_recs
# Out:
# 470144         1
# 470145         5
# 470146         9
# 470147        10
# 470150        31
#             ...
# 15140314    1375
# 15140315    1376
# 15140317    1383
# 15140318    1384
# 15140319    2019
# Name: movieId, Length: 9768, dtype: int64

# %%
similar_user_recs = similar_user_recs.value_counts()/len(similar_users)

# %%
similar_user_recs = similar_user_recs[similar_user_recs > .1]

# %%
similar_user_recs
# Out:
# movieId
# 137     1.000000
# 608     0.478261
# 1       0.434783
# 581     0.434783
# 260     0.434783
#           ...
# 2029    0.108696
# 2203    0.108696
# 1994    0.108696
# 124     0.108696
# 29      0.108696
# Name: count, Length: 557, dtype: float64

# %%
all_users = ratings[(ratings["movieId"].isin(similar_user_recs.index) & (ratings['rating'] >= 4))]

# %%
all_users
# Out:
#           userId  movieId  rating     timestamp
# 0              1      296     5.0  1.147880e+09
# 2              1      307     5.0  1.147869e+09
# 8              1     1237     5.0  1.147869e+09
# 9              1     1250     4.0  1.147868e+09
# 19             1     2692     5.0  1.147869e+09
# ...          ...      ...     ...           ...
# 15231530   98680     3147     5.0  1.437722e+09
# 15231534   98680     3175     4.0  1.498525e+09
# 15231575   98680     3671     5.0  1.437721e+09
# 15231620   98680     3996     4.0  1.437718e+09
# 15231644   98680     4306     4.0  1.437718e+09
#
# [2758473 rows x 4 columns]

# %%
all_user_recs = all_users["movieId"].value_counts() / len(all_users['userId'].unique())

# %%
all_user_recs
# Out:
# movieId
# 318     0.438732
# 296     0.388869
# 356     0.366746
# 593     0.360164
# 2571    0.347801
#           ...
# 1311    0.000319
# 138     0.000267
# 1471    0.000257
# 108     0.000257
# 660     0.000216
# Name: count, Length: 557, dtype: float64

# %% [markdown]
# **Now the prediction Model**

# %%
rec_perc = pd.concat([similar_user_recs, all_user_recs], axis = 1)
rec_perc.columns = ("similar", "all")

# %%
rec_perc
# Out:
#           similar       all
# movieId
# 137      1.000000  0.000473
# 608      0.478261  0.225542
# 1        0.434783  0.235858
# 581      0.434783  0.007909
# 260      0.434783  0.323662
# ...           ...       ...
# 2029     0.108696  0.001512
# 2203     0.108696  0.010995
# 1994     0.108696  0.029055
# 124      0.108696  0.000987
# 29       0.108696  0.035916
#
# [557 rows x 2 columns]

# %%
rec_perc["score"] = rec_perc['similar']/rec_perc['all']

# %%
rec_perc
# Out:
#           similar       all        score
# movieId
# 137      1.000000  0.000473  2113.652174
# 608      0.478261  0.225542     2.120496
# 1        0.434783  0.235858     1.843408
# 581      0.434783  0.007909    54.971448
# 260      0.434783  0.323662     1.343323
# ...           ...       ...          ...
# 2029     0.108696  0.001512    71.892931
# 2203     0.108696  0.010995     9.886119
# 1994     0.108696  0.029055     3.740977
# 124      0.108696  0.000987   110.086051
# 29       0.108696  0.035916     3.026421
#
# [557 rows x 3 columns]

# %%
rec_perc = rec_perc.sort_values('score', ascending = False)

# %%
rec_perc
# Out:
#           similar       all        score
# movieId
# 137      1.000000  0.000473  2113.652174
# 660      0.195652  0.000216   905.850932
# 138      0.217391  0.000267   812.943144
# 108      0.195652  0.000257   760.914783
# 601      0.239130  0.000329   726.567935
# ...           ...       ...          ...
# 4226     0.130435  0.199428     0.654044
# 2028     0.108696  0.211472     0.513995
# 2959     0.130435  0.292755     0.445542
# 4993     0.108696  0.259802     0.418379
# 2571     0.108696  0.347801     0.312523
#
# [557 rows x 3 columns]

# %%
records = rec_perc.merge(movies, left_index=True, right_on='movieId')

# %%
records
# Out:
#        similar       all        score  movieId  \
# 135   1.000000  0.000473  2113.652174      137
# 649   0.195652  0.000216   905.850932      660
# 136   0.217391  0.000267   812.943144      138
# 106   0.195652  0.000257   760.914783      108
# 593   0.239130  0.000329   726.567935      601
# ...        ...       ...          ...      ...
# 4122  0.130435  0.199428     0.654044     4226
# 1939  0.108696  0.211472     0.513995     2028
# 2867  0.130435  0.292755     0.445542     2959
# 4887  0.108696  0.259802     0.418379     4993
# 2480  0.108696  0.347801     0.312523     2571
#
#                                                   title  \
# 135                              Man of the Year (1995)
# 649                                       August (1996)
# 136                              Neon Bible, The (1995)
# 106                                      Catwalk (1996)
# 593           Wooden Man's Bride, The (Yan shen) (1994)
# ...                                                 ...
# 4122                                     Memento (2000)
# 1939                         Saving Private Ryan (1998)
# 2867                                  Fight Club (1999)
# 4887  Lord of the Rings: The Fellowship of the Ring,...
# 2480                                 Matrix, The (1999)
#
#                            genres  \
# 135                   Documentary
# 649                         Drama
# 136                         Drama
# 106                   Documentary
# 593                         Drama
# ...                           ...
# 4122             Mystery|Thriller
# 1939             Action|Drama|War
# 2867  Action|Crime|Drama|Thriller
# 4887            Adventure|Fantasy
# 2480       Action|Sci-Fi|Thriller
#
#                                           cleaned_title
# 135                                Man of the Year 1995
# 649                                         August 1996
# 136                                 Neon Bible The 1995
# 106                                        Catwalk 1996
# 593                 Wooden Mans Bride The Yan shen 1994
# ...                                                 ...
# 4122                                       Memento 2000
# 1939                           Saving Private Ryan 1998
# 2867                                    Fight Club 1999
# 4887  Lord of the Rings The Fellowship of the Ring T...
# 2480                                    Matrix The 1999
#
# [557 rows x 7 columns]

# %%
def find_similar_movies(movie_id):
    similar_users = ratings[(ratings["movieId"] == movie_id) & (ratings["rating"] >= 4)]["userId"].unique()
    similar_user_recs = ratings[(ratings['userId'].isin(similar_users)) & (ratings["rating"] >= 4)]['movieId']
    
    similar_user_recs = similar_user_recs.value_counts()/len(similar_users)
    similar_user_recs = similar_user_recs[similar_user_recs > .1]
    
    all_users = ratings[(ratings["movieId"].isin(similar_user_recs.index) & (ratings['rating'] >= 4))]
    all_user_recs = all_users["movieId"].value_counts() / len(all_users['userId'].unique())

    rec_perc = pd.concat([similar_user_recs, all_user_recs], axis = 1)
    rec_perc.columns = ("similar", "all")

    rec_perc["score"] = rec_perc['similar']/rec_perc['all']
    rec_perc = rec_perc.sort_values('score', ascending = False)

    records = rec_perc.merge(movies, left_index=True, right_on='movieId')
    return records['title'].head(10)

# %%
movie_name_input = widgets.Text(
    values='Type In:',
    description='Movie title: ',
    dasbled=False
)

recommendation_list = widgets.Output()

def on_type(data) :
    with recommendation_list:
        recommendation_list.clear_output()
        title = data ["new"]
        if len(title) > 3:
            results = search(title)
            movie_id = results. iloc[0]["movieId"]
            display(find_similar_movies(movie_id))

            
movie_name_input.observe(on_type, names="value")

display(movie_name_input, recommendation_list)
# Out:
# Text(value='', description='Movie title: ')
# Output()
